# %% [markdown]
# # Explore AI agents
#
# Five independent challenges. Run setup once, then choose an activity. No Python editing needed. All scenarios are fictional.
#
# The browser lab is the main route. This Colab companion uses the same tool functions and separate specialist calls. Module 2 opens the connected MCP lab.
#
# Add COURSE_API_KEY in Colab Secrets and enable notebook access.

# %%
#@title Prepare the exploration lab
import importlib.util, json, os, subprocess, sys, urllib.request
from pathlib import Path
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'openai==2.41.1', 'openpyxl==3.1.5', 'ipywidgets'], check=True)
from openai import OpenAI
from google.colab import userdata
BASE='https://raw.githubusercontent.com/FeikoWielsma/Using-AI-Agents/main/'
folder=Path('/content/agent-exploration');folder.mkdir(exist_ok=True)
for name in ['exploration_runtime.py','exploration_widgets.py']:
    urllib.request.urlretrieve(BASE+'notebooks/'+name,folder/name)
urllib.request.urlretrieve(BASE+'data/exploration-catalog.json',folder/'catalog.json')
urllib.request.urlretrieve(BASE+'data/menu-catalogue.json',folder/'menu-catalogue.json')
sys.path.insert(0,str(folder))
import exploration_runtime as runtime
from exploration_widgets import show
client=OpenAI(api_key=userdata.get('COURSE_API_KEY'),base_url='https://token-plan.ap-southeast-1.maas.aliyuncs.com/compatible-mode/v1',timeout=35,max_retries=0)
show(client,json.loads((folder/'catalog.json').read_text()))
